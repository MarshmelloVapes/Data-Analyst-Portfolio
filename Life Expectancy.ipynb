# %% [markdown]
# Project 1:
#
# This project was created to see the basics of year vs life expectancy.
# I used Canada as the base, however, added Zimbabwe also. The data for
# Zimbabwe only starts around 1950.
#
# This project was made using Jupyter note book.
#
# Data source:
# https://ourworldindata.org/life-expectancy
#
# Zimbabwe's drop in life expectancy:
# https://www.reuters.com/article/us-zimbabwe-election-decline-idUSL295874920080331

# %%
# Import Libaries
from ast import increment_lineno
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# Read in data
df = pd.read_csv('/Users/josh/Documents/Code/Data-Test-Life/life-expectancy.csv')

# %%
# Find missing data, if any.
for col in df.columns:
    pct_missing = np.mean (df[col].isnull())
    print ('{} - {}%'.format(col, pct_missing))
# Out:
# Entity - 0.0%
# Code - 0.030639058229976875%
# Year - 0.0%
# Life expectancy - 0.0%

# %%
# Data types for colums

df.dtypes
# Out:
# Entity              object
# Code                object
# Year                 int64
# Life expectancy    float64
# dtype: object

# %%
# Print the data.
df
# Out:
#             Entity Code  Year  Life expectancy
# 0      Afghanistan  AFG  1950           27.638
# 1      Afghanistan  AFG  1951           27.878
# 2      Afghanistan  AFG  1952           28.361
# 3      Afghanistan  AFG  1953           28.852
# 4      Afghanistan  AFG  1954           29.350
# ...            ...  ...   ...              ...
# 19023     Zimbabwe  ZWE  2015           59.534
# 19024     Zimbabwe  ZWE  2016           60.294
# 19025     Zimbabwe  ZWE  2017           60.812
# 19026     Zimbabwe  ZWE  2018           61.195
# 19027     Zimbabwe  ZWE  2019           61.490
#
# [19028 rows x 4 columns]

# %%
# Get values for Canada only
df1 = df.loc[df["Entity"] == "Canada"]

# Get values for Zimbabwe only
df2 = df.loc[df["Entity"] == "Zimbabwe"]

df1
# Out:
#       Entity Code  Year  Life expectancy
# 2937  Canada  CAN  1831        39.046398
# 2938  Canada  CAN  1841        40.317200
# 2939  Canada  CAN  1851        41.059681
# 2940  Canada  CAN  1861        41.595039
# 2941  Canada  CAN  1871        42.556801
# ...      ...  ...   ...              ...
# 3040  Canada  CAN  2015        82.026000
# 3041  Canada  CAN  2016        82.117000
# 3042  Canada  CAN  2017        82.210000
# 3043  Canada  CAN  2018        82.315000
# 3044  Canada  CAN  2019        82.434000
#
# [108 rows x 4 columns]

# %%
# Compare year to life expectancy in Canada
# Scatter plot, year vs life expectancy.
plt.scatter(x=df1['Year'], y=df1['Life expectancy'])
plt.title('Year vs Life expectancy in Canada')
plt.xlabel('Year')
plt.ylabel('Life expectancy')
plt.show()

# %%
# Seaborn, plot year vs life expectancy in Canada
sns.regplot(x='Year', y='Life expectancy', data=df1, scatter_kws={"color": "red"}, line_kws={"color": "black"})
plt.title('Year vs Life expectancy in Canada')
plt.show()

# %%
# Mark correlation
#visualize info
correlation = df1.corr()

sns.heatmap(correlation, annot=True)
plt.title('Correlation in Canada')
plt.show()

# %%
# Compare year to life expectancy in Zimbabwe.
# Scatter plot, year vs life expectancy.
plt.scatter(x=df2['Year'], y=df2['Life expectancy'], color="blue")
plt.title('Year vs Life expectancy in Zimbabwe')
plt.xlabel('Year')
plt.ylabel('Life expectancy')
plt.show()

# %%
# Seaborn, plot year vs life expectancy in Zimbabwe
sns.regplot(x='Year', y='Life expectancy', data=df2, scatter_kws={"color": "blue"}, line_kws={"color": "black"})
plt.title('Year vs Life expectancy in Zimbabwe')
plt.show()

# %%
# Graph data from Canada and Zimbabwe to compare.
sns.regplot(x='Year', y='Life expectancy', data=df1, 
            scatter_kws={"color": "red"}, label='Canada')
sns.regplot(x='Year', y='Life expectancy', data=df2, 
            scatter_kws={"color": "blue"}, label='Zimbabwe')
plt.xlim(1945,2022)
plt.ylim(40, 90)
plt.legend(loc="best")
plt.title('Life Expectancy Canada vs Zimbabwe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
